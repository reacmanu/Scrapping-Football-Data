# %%
from statsbombpy import sb

# %%
# show all competitions
sb.competitions()

# show unique competitions
sb.competitions().drop_duplicates(['country_name', 'competition_name'])
# Out:
# e:\manu\ana\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 15              37         90                   England
# 18              43          3             International
# 19            1238        108                     India
# 20              11         90                     Spain
# 37              49          3  United States of America
# 38               2         44                   England
# 39              55         43                    Europe
# 40              53        106                    Europe
# 41              72         30             International
#
#            competition_name competition_gender  competition_youth  \
# 0          Champions League               male              False
# 15  FA Women's Super League             female              False
# ...

# %%
pl = sb.matches(competition_id=2, season_id=44)
# Out:
# e:\manu\ana\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
pl.head(5)
# Out:
#    match_id  match_date      kick_off               competition     season  \
# 0   3749052  2004-02-07  16:00:00.000  England - Premier League  2003/2004
# 1   3749522  2003-12-26  13:00:00.000  England - Premier League  2003/2004
# 2   3749246  2004-03-28  17:05:00.000  England - Premier League  2003/2004
# 3   3749257  2004-05-15  16:00:00.000  England - Premier League  2003/2004
# 4   3749642  2004-02-28  16:00:00.000  England - Premier League  2003/2004
#
#                  home_team                away_team  home_score  away_score  \
# 0  Wolverhampton Wanderers                  Arsenal           1           3
# 1                  Arsenal  Wolverhampton Wanderers           3           0
# 2                  Arsenal        Manchester United           1           1
# 3                  Arsenal           Leicester City           2           1
# 4                  Arsenal        Charlton Athletic           2           1
#
# ...

# %%
mat_id = 3749246
pl[pl['match_id']==mat_id]
# Out:
#    match_id  match_date      kick_off               competition     season  \
# 2   3749246  2004-03-28  17:05:00.000  England - Premier League  2003/2004
#
#   home_team          away_team  home_score  away_score match_status  ...  \
# 2   Arsenal  Manchester United           1           1    available  ...
#
#        last_updated         last_updated_360 match_week  competition_stage  \
# 2  2020-07-29T05:00  2021-06-13T16:17:31.694         30     Regular Season
#
#             stadium  home_managers  away_managers data_version  \
# 2  Highbury Stadium  Arsène Wenger  Alex Ferguson        1.1.0
#
#   shot_fidelity_version xy_fidelity_version
# 2                     2                   2
#
# [1 rows x 21 columns]

# %%
lineups = sb.lineups(match_id=mat_id)
# Out:
# e:\manu\ana\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
lineups['Arsenal']
# Out:
#     player_id                      player_name     player_nickname  \
# 0       15042                  Dennis Bergkamp                None
# 1       15515                   Patrick Vieira                None
# 2       15516                    Thierry Henry                None
# 3       15637  Sulzeer Jeremiah "Sol" Campbell        Sol Campbell
# 4       15754                Fredrik Ljungberg                None
# 5       19312                    Robert Pirès                 None
# 6       20015                     Jens Lehmann                None
# 7       20302                      Gaël Clichy                None
# 8       23816      José Antonio Reyes Calderón  José Antonio Reyes
# 9       24971           Nwankwo Christian Kanu                None
# 10      26014       Eduardo César Daude Gaspar          Edu Gaspar
# 11      26194                     Pascal Cygan                None
# 12      38412                 Kolo Habib Touré          Kolo Touré
# ...

# %%
lineups['Manchester United']
# Out:
#     player_id                player_name       player_nickname  jersey_number  \
# 0        4022            Darren Fletcher                  None             24
# 1       13042                 Tim Howard                  None             14
# 2       15402               Gary Neville                  None              2
# 3       15590        Ole Gunnar Solskjær  Ole Gunnar Solskjaer             20
# 4       15660               Phil Neville                  None              3
# 5       15666               Paul Scholes                  None             18
# 6       16890                John O"Shea           John O'Shea             22
# 7       19729        Ruud van Nistelrooy   Ruud van Nistelrooy             10
# 8       20175                 Ryan Giggs                  None             11
# 9       20341           Mikaël Silvestre                  None             27
# 10      20505                 Louis Saha                  None              9
# ...

# %%
df_events = sb.events(match_id=mat_id)
# Out:
# e:\manu\ana\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
df_events.columns
# Out:
# Index(['50_50', 'ball_receipt_outcome', 'ball_recovery_recovery_failure',
#        'block_offensive', 'carry_end_location', 'clearance_aerial_won',
#        'clearance_body_part', 'clearance_head', 'clearance_left_foot',
#        'clearance_right_foot', 'counterpress', 'dribble_outcome',
#        'dribble_overrun', 'duel_outcome', 'duel_type', 'duration',
#        'foul_committed_advantage', 'foul_committed_card', 'foul_won_advantage',
#        'foul_won_defensive', 'goalkeeper_body_part', 'goalkeeper_end_location',
#        'goalkeeper_outcome', 'goalkeeper_position', 'goalkeeper_punched_out',
#        'goalkeeper_success_in_play', 'goalkeeper_technique', 'goalkeeper_type',
#        'id', 'index', 'interception_outcome', 'location', 'match_id', 'minute',
#        'miscontrol_aerial_won', 'off_camera', 'out', 'pass_aerial_won',
#        'pass_angle', 'pass_assisted_shot_id', 'pass_body_part', 'pass_cross',
#        'pass_cut_back', 'pass_deflected', 'pass_end_location',
# ...

# %%
df_events = df_events[['timestamp','team', 'type', 'minute', 'location', 'pass_end_location', 'player']]
df_events = df_events.sort_values(['minute', 'timestamp'])

# %%
df_events.tail(30)
# Out:
#          timestamp               team           type  minute       location  \
# 2129  00:47:32.520  Manchester United          Carry      92   [23.1, 25.1]
# 2583  00:47:32.520  Manchester United  Ball Recovery      92   [23.1, 25.1]
# 2458  00:47:33.020            Arsenal       Pressure      92  [105.3, 54.5]
# 2771  00:47:34.227  Manchester United   Dispossessed      92   [21.1, 26.9]
# 2868  00:47:34.227            Arsenal           Duel      92   [99.0, 53.2]
# 829   00:47:35.075  Manchester United           Pass      92   [16.7, 28.4]
# 2584  00:47:36.192            Arsenal  Ball Recovery      92   [77.2, 52.6]
# 2130  00:47:38.596            Arsenal          Carry      92   [61.7, 44.0]
# 2585  00:47:38.596            Arsenal  Ball Recovery      92   [61.7, 44.0]
# 2459  00:47:39.326  Manchester United       Pressure      92   [56.4, 40.2]
# 830   00:47:42.100            Arsenal           Pass      92   [83.3, 52.6]
# ...
